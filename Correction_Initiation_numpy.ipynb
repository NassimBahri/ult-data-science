# %% [markdown]
# Dans ce premier Lab, nous essayerons de manipuler les fonctions de base de la bibliothèque numérique numpy.

# %% [markdown]
# # Les bases de la bibliothèque NumPy

# %%
## Code à compléter
# Installer la bibliothèque numpy (si elle n'est pas encore installée)
# Importer la bibliothèque numpy
import numpy as np

# %% [markdown]
# ### Exercice 1
# Ecrire un programme NumPy permettant de convertir une liste de valeurs numériques à un array NumPy unidimensionnel.

# %%
## Code à compléter
liste = [10, 15, 32.5, 11]
tab = np.array(liste)
print(type(tab))
tab
# Out:
# <class 'numpy.ndarray'>
# array([10. , 15. , 32.5, 11. ])

# %% [markdown]
# ### Exercice 2
# Ecrire un programme NumPy permettant de créer une matrice 3x3 avec des valeurs allant de 2 à 10. Output:
#
# `[ [ 2 3 4]
# [ 5 6 7]
# [ 8 9 10] ]`

# %%
## Code à compléter
tab = np.arange(2, 11).reshape(3, 3)
tab
# Out:
# array([[ 2,  3,  4],
#        [ 5,  6,  7],
#        [ 8,  9, 10]])

# %% [markdown]
# ### Exercice 3
# Ecrire un programme qui permet de créer un tableau de dimension 5 x 5 avec des valeurs aléatoires et de trouver les
# valeur mininales et maximales.

# %%
## Code à compléter
tab = np.random.rand(25).reshape(5, 5)            # Tableau qui contient des chiffres 0 < x < 1
tab = np.random.randint(1, 999, 25).reshape(5, 5) # Tableau qui contient des chiffres 1 <= x < 999
print("Tableau initial :", tab)
print("Valeur minimale :", tab.min())
print("Valeur maximale :", tab.max())
# Out:
# Tableau initial : [[984 208 290 509 753]
#  [ 52 852 778  91 901]
#  [429 722 629   5 350]
#  [775 246 143 781 132]
#  [482  19 844 344   7]]
# Valeur minimale : 5
# Valeur maximale : 984

# %% [markdown]
# ### Exercice 4
# Créer une fonction python qui permet de renvoyer une matrice respectant les exigences suivantes.

# %%
## Code à compléter
def init(m, n):
    # m : Nombre de lignes
    # n : Nombre de colonnes
    # Retourne une matrice aléatoire (m, n+1) avec une colonne bias (remplie de "1") tout à droite
    matrice = np.random.randn(m, n) # Génére des nombres aléatoires en se basant sur le distribution normale
    bias = np.ones((m, 1))
    return np.concatenate([matrice, bias], axis=1)

resultat = init(4, 2)
resultat
# Out:
# array([[-0.365379  ,  0.76021447,  1.        ],
#        [ 0.18825951,  0.13822933,  1.        ],
#        [-1.40107713,  0.71412245,  1.        ],
#        [ 0.7901173 , -1.0523044 ,  1.        ]])

# %% [markdown]
# # Manipulation d'une image avec NumPy
# Dans cet exemple, nous essayerons de manipuler des images sous la forme de tableau NumPy à n-dimensions. C'est la base de tous les algorithmes de Deep Learning (Computer Vision).

# %%
# Importer l'image à manipuler
from scipy import misc
import matplotlib.pyplot as plt
face = misc.face()
plt.imshow(face, cmap=plt.cm.gray)
plt.show()
# Out:
# <ipython-input-8-0df101729add>:4: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face()

# %%
face
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
#         ...,
#         [120, 156,  95],
#         [119, 155,  93],
#         [118, 154,  92]]], dtype=uint8)

# %%
tab = np.array([255, 255, 255, 0, 0, 100, 0, 50, 0]).reshape(3, 3)
plt.imshow(tab)
plt.show()

# %% [markdown]
# Pour réduire la complexité de notre tableau NumPy, on va changer cette image sans couleur (c'est à dire en version noir et blanc). Il faut tout simplement utiliser la fonction : `misc.face(gray=True)`

# %%
## Code à compléter
face = misc.face(gray=True)
plt.imshow(face, cmap=plt.cm.gray)
plt.show()
face.shape
# Out:
# <ipython-input-15-912c4993c957>:2: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face(gray=True)
# (768, 1024)

# %%
face
# Out:
# array([[114, 130, 145, ..., 119, 129, 137],
#        [ 83, 104, 123, ..., 118, 134, 146],
#        [ 68,  88, 109, ..., 119, 134, 145],
#        ...,
#        [ 98, 103, 116, ..., 144, 143, 143],
#        [ 94, 104, 120, ..., 143, 142, 142],
#        [ 94, 106, 119, ..., 142, 141, 140]], dtype=uint8)

# %% [markdown]
# ### Question 1
# Zoom sur une partie de l'image : zoomer de 1/4 vers le milieu pour cette photo)

# %%
## Code à compléter
face = misc.face(gray=True)
plt.imshow(face, cmap=plt.cm.gray)
l, c = face.shape
margin_l = l // 4
margin_c = c // 4
print(margin_l, margin_c)
image = face[margin_l: -margin_l, margin_c:-margin_c]
plt.imshow(image)
plt.show()
# Out:
# <ipython-input-25-48ba75fe382d>:2: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face(gray=True)
# 192 256

# %%
from PIL import Image
img = Image.open("image.jpg")
np.asarray(img)
# Out:
# array([[[ 25,  26,  12],
#         [ 25,  26,  12],
#         [ 25,  26,  12],
#         ...,
#         [113, 106,  52],
#         [113, 106,  52],
#         [114, 107,  53]],
#
#        [[ 25,  26,  12],
#         [ 25,  26,  12],
#         [ 25,  26,  12],
#         ...,
#         [113, 106,  52],
#         [113, 106,  52],
#         [114, 107,  53]],
#
#        [[ 25,  26,  12],
#         [ 25,  26,  12],
#         [ 25,  26,  12],
#         ...,
#         [112, 105,  51],
#         [113, 106,  52],
#         [113, 106,  52]],
#
#        ...,
#
#        [[139, 118,  71],
#         [136, 115,  68],
#         [130, 109,  62],
#         ...,
#         [ 67,  91,  91],
#         [ 68,  89,  90],
#         [ 66,  88,  86]],
#
#        [[150, 128,  81],
#         [143, 121,  74],
#         [134, 111,  67],
#         ...,
#         [ 73,  93,  91],
#         [ 69,  89,  87],
#         [ 65,  85,  83]],
#
#        [[151, 127,  81],
#         [144, 120,  74],
#         [135, 111,  67],
#         ...,
#         [ 74,  93,  91],
#         [ 70,  89,  85],
#         [ 66,  85,  81]]], dtype=uint8)

# %% [markdown]
# ### Question 2
# Réduire la taille de la photo (compression) à la moitié

# %%
## Code à compléter
face = misc.face()
img = face[::10, ::10]
plt.imshow(img)
# Out:
# <ipython-input-35-b4f3b2d11b94>:2: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face()

# %% [markdown]
# ### Question 3
# Convertir l'image en noir et blanc (On va supprimer le niveau de gris).

# %%
## Code à compléter
face = misc.face(gray=True)
img = face.copy()
img[face > 100] = 255
img[face <= 100] = 0
plt.imshow(img, cmap=plt.cm.gray)
# Out:
# <ipython-input-44-dd19fe01c513>:2: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face(gray=True)
