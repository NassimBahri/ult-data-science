# %%
# Importer les packages nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Créer une datafarame des étudiants
etudiants = pd.DataFrame({
    "nom": ["Etudiant 1", "Etudiant 2", "Etudiant 3", "Etudiant 4", "Etudiant 5", "Etudiant 6", "Etudiant 7", "Etudiant 8", "Etudiant 9", "Etudiant 10"],
    "pays": ["Tunisie", "Niger", "Niger", "Algerie", np.nan, "Tunisie", "Maroc", "Tunisie", "Gabon", "Tunisie"],
    "bac": ["Math", "Science", "Info", "Math", "Math", "Info", "Eco", "Info", np.nan, np.nan],
    "moyenne_bac": [11, 12.5, 10, 15.75, 21.5, 16.75, 16.77, 12.32, 11.65, 10],
    "age": [19, 21, 19, 19, 19, 23, 19, np.nan, 19, 25],
    "niveau_francais": ["Bien", "T.Bien", "Moyen", "Bon", "Bien", "T.Bien", "Mauvais", "Bien", "Mauvais", "T.Bien"],
    "sexe": ["homme", "femme", "femme", "f", "homme", "mr", "homme", "femme", "femme", "femme"]
})

# %%
# Afficher la liste des étudiants
etudiants
# Out:
#            nom     pays      bac  moyenne_bac   age niveau_francais   sexe
# 0   Etudiant 1  Tunisie     Math        11.00  19.0            Bien  homme
# 1   Etudiant 2    Niger  Science        12.50  21.0          T.Bien  femme
# 2   Etudiant 3    Niger     Info        10.00  19.0           Moyen  femme
# 3   Etudiant 4  Algerie     Math        15.75  19.0             Bon      f
# 4   Etudiant 5      NaN     Math        21.50  19.0            Bien  homme
# 5   Etudiant 6  Tunisie     Info        16.75  23.0          T.Bien     mr
# 6   Etudiant 7    Maroc      Eco        16.77  19.0         Mauvais  homme
# 7   Etudiant 8  Tunisie     Info        12.32   NaN            Bien  femme
# 8   Etudiant 9    Gabon      NaN        11.65  19.0         Mauvais  femme
# 9  Etudiant 10  Tunisie      NaN        10.00  25.0          T.Bien  femme
